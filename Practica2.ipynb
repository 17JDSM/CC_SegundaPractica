# %% [markdown]
# # **Complejidad Computacional**
# **Complejidad Algorítmica**
#
# **Profesor:** Luis Chamba-Eras
#
# **Nombre:** Jonathan David Sefla Macas 4to B

# %% [markdown]
# # **Complejidad algorítmica**
# Nos permite comparar la eficiencia de 2 algoritmos, con el objetivo de predecir el tiempo que va a tomar resolver un problema.
# Se puede analizar de dos perspectivas:
# *   Temporal
# *   Espacial
#
# La complejidad algorítmica temporal la podemos definir como **T(n)** el cual determinara el tiempo que demora en resolver nuestro algoritmo.
#
# Se puede aplicar la función T(n) para:
#
#
# *   Cronometrar el tiempo en el que corre un algoritmo (no es una buena forma de medir los algoritmos).
# *   Contar los pasos con una medida abstracta de operación (varia mucho).
# *   Contar los pasos conforme nos aproximamos al infinito pero con una medida asintótica.

# %% [markdown]
# **Medición temporal**
# Para una realizar una medida temporal simplemente calculamos la diferencia del tiempo previo y posterior de la ejecución del algoritmo.

# %%
import time

def factorial(n):
    respuesta = 1

    while n > 1:
        respuesta *= n
        n -= 1

    return respuesta

def factorial_r(n):
    if n == 1:
        return 1

    return n * factorial(n - 1)

if __name__ == '__main__':
    n = 250000

    comienzo = time.time()
    factorial(n)
    final = time.time()
    print(final - comienzo)

    comienzo = time.time()
    factorial_r(n)
    final = time.time()
    print(final - comienzo)
# Out:
# 25.375996828079224
# 25.277588367462158

# %% [markdown]
# **Conteo abstracto de operación**
# Con esta técnica contamos los pasos que realiza nuestro algoritmo.
# Ejemplo en código:

# %%
def f(x):

    respuesta = 0

    for i in range(1000):
        respuesta += 1

    for i in range(x):
        respuesta += x

    for i in range(x):
        for j in range(x):
            respuesta += 1
            respuesta += 1

    return respuesta

# print("Respuesta: ", f(3000))
# Out:
# Respuesta:  27001000

# %% [markdown]
# **Notación asintótica**
#
# El enfoque  de la notación asintótica se centra en lo que pasa conforme el tamaño del problema se acerca al infinito.
#
# Lo mejor que nos permite comparar nuestros algoritmos y su capacidad es medir el peor de los casos, ahí es donde entra el **Big O notation**, donde lo único que importa es el termino de mayor tamaño, sin importar las constantes que las acompañan.
#
# Ejemplos:

# %% [markdown]
# **Ley de la suma**

# %%
def f(n):
    for i in range(n):
        print(i)

    for i in range(n):
        print(i)

# %% [markdown]
# En este caso el mayor término es n
#
#
# O(n) + O(n) = O(n + n) = O(2n) = O(n)

# %% [markdown]
# **Ley de la suma**

# %%
# Ley de la suma

def f(n):
    for i in range(n):
        print(i)

    for i in range(n * n):
        print(i)

# %% [markdown]
# En este caso el mayor término es n²
#
# O(n) + O(n * n) = O(n + n²) = O(n²)

# %% [markdown]
# **Ley de la multiplicación**

# %%
def f(n):

    for i in range(n):

        for i in range(n):
            print(i, j)

# %% [markdown]
# En este caso el mayor término es n²
#
# O(n) + O(n * n) = O(n * n) = O(n²)

# %% [markdown]
# **Recursividad múltiple**

# %%
def fibonacci(n):

    if n == 0 or n == 1:
        return 1

    return fibonacci(n - 1) +  fibonacci(n - 2)

# %% [markdown]
# En este caso el mayor término es 2 ** n (el símbolo ** denota "elevado a"), ya que realiza recursividad 2 veces por n veces.
#  O(2**n)

# %% [markdown]
# ***Clases de complejidad algorítmica***
#
# ![tipos de complejidad algoritmica.png](data:image/png;base64,...)

# %% [markdown]
# ***Algoritmos de búsqueda y ordenación***
#
# La *búsqueda lineal* es un algoritmo muy sencillo. Consta en buscar si un elemento se encuentra dentro de una lista, array o un sistema ordenado o no ordenado para poder determinar si el elemento se encuentra en el o forma parte de el.

# %%
import random

def busqueda_lineal(lista, objetivo):
    match = False

    for elemento in lista: # O(n)
        if elemento == objetivo:
            match = True
            break
    return match


if __name__ == '__main__':
    tamano_de_lista = int(input('De que tamano sera la lista? '))
    objetivo = int(input('Que numero quieres encontrar? '))

    lista = [random.randint(0, 100) for i in range(tamano_de_lista)]

    encontrado = busqueda_lineal(lista, objetivo)
    print(lista)
    print(f'El elemento {objetivo} {"esta" if encontrado else "no esta"} en la lista')
# Out:
# De que tamano sera la lista? 23000
# Que numero quieres encontrar? 5
# [2, 77, 52, 60, 87, 14, 10, 53, 49, 2, 35, 82, 47, 57, 4, 88, 73, 44, 28, 72, 87, 17, 76, 13, 34, 74, 27, 29, 44, 62, 24, 26, 28, 9, 10, 65, 89, 7, 73, 96, 100, 94, 73, 83, 4, 57, 88, 69, 52, 54, 67, 45, 32, 39, 90, 56, 0, 38, 75, 38, 89, 84, 63, 56, 89, 6, 29, 85, 71, 52, 2, 99, 0, 29, 4, 42, 63, 74, 1, 84, 13, 26, 90, 78, 99, 18, 32, 12, 57, 46, 42, 33, 23, 52, 32, 51, 26, 40, 72, 90, 92, 0, 18, 75, 53, 68, 19, 95, 17, 40, 78, 36, 40, 34, 43, 61, 94, 32, 21, 53, 83, 26, 11, 24, 53, 30, 17, 36, 11, 55, 62, 94, 38, 0, 62, 55, 93, 81, 25, 77, 45, 33, 75, 35, 14, 27, 6, 69, 15, 38, 13, 12, 14, 65, 85, 30, 100, 65, 64, 53, 4, 67, 20, 20, 12, 1, 66, 94, 38, 71, 69, 30, 66, 26, 65, 81, 9, 38, 39, 75, 62, 55, 6, 20, 5, 85, 99, 43, 59, 49, 4, 34, 42, 11, 82, 86, 97, 50, 24, 95, 95, 55, 35, 21, 57, 46, 83, 91, 7, 76, 72, 95, 8, 53, 39, 44, 7, 37, 79, 40, 8, 35, 73, 31, 42, 74, 31, 99, 50, 100, 68, 25, 68, 49, 78, 36, 19, 87, 57, 31, 73, 76, 41, 61, 95, 32, 59, 18, 80, 81, 87, 61, 59, 40, 15, 5, 8, 78, 27, 12, 25, 68, 15, 26, 45, 41, 17, 12, 61, 12, 25, 16, 3, 3, 89, 65, 73, 21, 27, 20, 82, 58, 87, 32, 92, 1, 28, 76, 33, 29, 64, 49, 96, 97, 76, 51, 77, 8, 96, 64, 42, 72, 68, 19, 42, 99, 34, 79, 66, 13, 85, 88, 67, 63, 97, 60, 32, 59, 98, 31, 41, 33, 40, 1, 77, 59, 80, 25, 91, 22, 12, 3, 44, 37
 19, 26, 7, 92, 35, 79, 70, 65, 45, 62, 6, 11, 79, 54, 49, 13, 28, 49, 38, 97, 86, 97, 99, 11, 74, 78, 68, 39, 1, 64, 67, 98, 47, 58, 19, 37, 1, 80, 73, 43, 91, 22, 12, 54, 93, 93, 46, 62, 45, 78, 19, 64, 0, 1, 25, 22, 94, 86, 20, 13, 52, 80, 48, 7, 1, 67, 49, 98, 30, 52, 13, 26, 27, 28, 79, 18, 83, 19, 43, 41, 95, 95, 90, 3, 26, 56, 2, 46, 59, 42, 0, 3, 94, 91, 69, 23, 62, 29, 69, 2, 26, 50, 58, 82, 35, 88, 72, 20, 96, 56, 17, 70, 36, 73, 48, 47, 52, 97, 45, 45, 75, 56, 26, 43, 8, 27, 24, 96, 5, 47, 9, 70, 22, 47, 80, 37, 42, 65, 81, 90, 53, 0, 50, 53, 62, 1, 73, 45, 90, 12, 97, 60, 40, 93, 54, 58, 69, 4, 65, 10, 1, 74, 24, 44, 31, 43, 20, 93, 10, 9, 71, 21, 80, 26, 78, 57, 82, 74, 69, 88, 8, 43, 26, 19, 84, 88, 69, 6, 15, ...
# El elemento 5 esta en la lista

# %% [markdown]
# Existe un for loop que crece según el tamaño de la lista, por lo cual nuestro Big O es O(n).

# %% [markdown]
# **Búsqueda binaria**
#
# Tiene como estrategia llamada "Divide y conquista", la cual consiste en dividir el problema en 2 en cada iteración. Es necesario tener la lista ordenada.
#
# Ventaja: Reduce significativamente el numero de pasos, y así disminuyendo nuestro Big O.
#
# *Mejor de los Casos*
#
#
# ![mejor de los casos.gif](data:image/gif;base64,...)

# %% [markdown]
# Ejemplo búsqueda binaria

# %%
import random

def busqueda_binaria(lista, comienzo, final, objetivo):
    print(f'buscando {objetivo} entre {lista[comienzo]} y {lista[final - 1]}')
    if comienzo > final:
        return False

    medio = (comienzo + final) // 2

    if lista[medio] == objetivo:
        return True
    elif lista[medio] < objetivo:
        return busqueda_binaria(lista, medio + 1, final, objetivo)
    else:
        return busqueda_binaria(lista, comienzo, medio - 1, objetivo)


if __name__ == '__main__':
    tamano_de_lista = int(input('De que tamano es la lista? '))
    objetivo = int(input('Que numero quieres encontrar? '))

    lista = sorted([random.randint(0, 10000) for i in range(tamano_de_lista)])

    encontrado = busqueda_binaria(lista, 0, len(lista), objetivo)

    print(lista)
    print(f'El elemento {objetivo} {"esta" if encontrado else "no esta"} en la lista')
# Out:
# De que tamano es la lista? 9999
# Que numero quieres encontrar? 7766
# buscando 7766 entre 1 y 10000
# buscando 7766 entre 5037 y 10000
# buscando 7766 entre 7519 y 10000
# buscando 7766 entre 7519 y 8728
# buscando 7766 entre 7519 y 8126
# buscando 7766 entre 7519 y 7801
# buscando 7766 entre 7669 y 7801
# buscando 7766 entre 7739 y 7801
# buscando 7766 entre 7739 y 7773
# buscando 7766 entre 7754 y 7773
520, 520, 522, 522, 524, 526, 526, 526, 527, 527, 528, 528, 528, 530, 531, 533, 534, 535, 536, 537, 537, 537, 538, 539, 539, 540, 540, 542, 542, 543, 543, 545, 546, 548, 549, 552, 553, 554, 554, 554, 554, 555, 557, 560, 561, 561, 562, 565, 566, 567, 567, 568, 568, 569, 571, 571, 571, 572, 573, 573, 575, 575, 576, 576, 578, 579, 583, 584, 585, 586, 586, 587, 588, 590, 592, 594, 595, 596, 596, 597, 598, 599, 599, 601, 604, 606, 606, 607, 608, 609, 610, 610, 613, 613, 614, 614, 615, 616, 618, 619, 621, 621, 621, 622, 622, 622, 625, 625, 626, 626, 627, 627, 629, 629, 633, 634, 635, 639, 641, 643, 644, 644, 644, 645, 646, 647, 653, 654, 656, 657, 657, 658, 660, 664, 665, 666, 667, 667, 667, 668, 673, 673, 674, 675, 677, 679, 680, 682, 682, 682, 682, 683, 683, 683, 685, 685, 686, 689, 691, 692, 692, 695, 695, 696, 696, 698, 700, 700, 700, 700, 701, 701, 704, 705, 705, 707, 707, 708, 708, 712, 712, 712, 712, 715, 716, 718, 720, 722, 722, 724, 724, 724, 725, 725, 726, 726, 727, 728, 729, 730, 731, 731, 732, 733, 734, 735, 736, 738, 738, 740, 741, 743, 745, 745, 745, 747, 748, 752, 752, 753, 753, 753, 754, 755, 755, 756, 758, 762, 768, 768, 769, 770, 771, 773, 773, 775, 776, 777, 780, 780, 781, 781, 782, 782, 784, 786, 787, 790, 791, 793, 794, 795, 795, 796, 796, 797, 799, 803, 804, 805, 807, 808, 808, 809, 816, 817, 819, 820, 821, 821, 824, 824, 825, 826, 827, 828, 828, 829, 834, 835, 835, 836, 838, 841, 841, 843, 843, 845, 846, 849, 849, 850, 850, 854, 854, 857, 857, 8 ...
# El elemento 7766 esta en la lista

# %% [markdown]
# **Ordenamiento de burbuja**
#
# Es un algoritmo que recorre repetidamente una lista que necesita ordenarse. Compara elementos adyacentes y los intercambia si están en el orden incorrecto. Este procedimiento se repite hasta que no se requiere mas intercambios, lo que indica que la lista se encuentra ordenada.
#
# Ejemplo:

# %%
import random


def ordenamiento_de_burbuja(lista):
    n = len(lista)

    for i in range(n):
        for j in range(0, n - i - 1): # O(n) * O(n) = O(n * n) = O(n**2)

            if lista[j] > lista[j + 1]:
                lista[j], lista[j + 1] = lista[j + 1], lista[j]

    return lista

if __name__ == '__main__':
    tamano_de_lista = int(input('De que tamano sera la lista? '))

    lista = [random.randint(0, 100) for i in range(tamano_de_lista)]
    print(lista)

    lista_ordenada = ordenamiento_de_burbuja(lista)
    print(lista_ordenada)
# Out:
# De que tamano sera la lista? 100
# [50, 20, 4, 17, 25, 1, 53, 25, 90, 37, 54, 59, 44, 17, 59, 78, 49, 63, 20, 71, 56, 99, 60, 54, 5, 79, 43, 16, 79, 9, 53, 56, 34, 87, 60, 2, 61, 24, 59, 18, 90, 87, 16, 20, 76, 16, 9, 39, 22, 90, 99, 12, 96, 42, 9, 57, 8, 12, 28, 50, 1, 46, 7, 52, 69, 14, 35, 36, 27, 14, 19, 75, 37, 59, 34, 27, 17, 63, 78, 27, 25, 48, 13, 83, 43, 13, 40, 26, 66, 29, 20, 24, 9, 25, 23, 46, 83, 73, 88, 89]
# [1, 1, 2, 4, 5, 7, 8, 9, 9, 9, 9, 12, 12, 13, 13, 14, 14, 16, 16, 16, 17, 17, 17, 18, 19, 20, 20, 20, 20, 22, 23, 24, 24, 25, 25, 25, 25, 26, 27, 27, 27, 28, 29, 34, 34, 35, 36, 37, 37, 39, 40, 42, 43, 43, 44, 46, 46, 48, 49, 50, 50, 52, 53, 53, 54, 54, 56, 56, 57, 59, 59, 59, 59, 60, 60, 61, 63, 63, 66, 69, 71, 73, 75, 76, 78, 78, 79, 79, 83, 83, 87, 87, 88, 89, 90, 90, 90, 96, 99, 99]

# %% [markdown]
# **Ordenamiento por inserción**
#
# Es intuitivo y fácil de implementar, pero es muy ineficiente para listas de gran tamaño.
#
# Definción:
#
# Una lista es dividida entre una sublista ordenada y otra sublista desordenada. Al principio, la sublista ordenada contiene un solo elemento, por lo que por definición se encuentra ordenada.
#
# A continuación se evalua el primer elemento dentro la sublista desordenada para que podamos insertarlo en el lugar correcto dentro de la lista ordenada.
#
# La inserción se realiza al mover todos los elementos mayores al elemento que se está evauluando un lugar a la derecha.
#
# Continua el proceso hasta que la sublista desordenada quede vacia y, por lo tanto, la lista se encontrará ordenada.
#
# Implementación:

# %%
def ordenamiento_por_insercion(lista):

    for indice in range(1, len(lista)):
        valor_actual = lista[indice]
        posicion_actual = indice

        while posicion_actual > 0 and lista[posicion_actual - 1] > valor_actual:
            lista[posicion_actual] = lista[posicion_actual - 1]
            posicion_actual -= 1

        lista[posicion_actual] = valor_actual

# %% [markdown]
# **Ordenamiento por mezcla**
#
# El ordenamiento por mezcla creado por John von Neumann el cual aplica el concepto de "divide y conquista". Primero divide una lista en partes iguales hasta que quedan sublistas de 1 o 0 elementos. Luego las recombina en forma ordenada.

# %%
import random

def ordenamiento_por_mezcla(lista):
    if len(lista) > 1:
        medio = len(lista) // 2
        izquierda = lista[:medio]
        derecha = lista[medio:]
        print(izquierda, '*' * 5, derecha)

        # llamada recursiva en cada mitad
        ordenamiento_por_mezcla(izquierda)
        ordenamiento_por_mezcla(derecha)

        # Iteradores para recorrer las dos sublistas
        i = 0
        j = 0
        # Iterador para la lista principal
        k = 0

        while i < len(izquierda) and j < len(derecha):
            if izquierda[i] < derecha[j]:
                lista[k] = izquierda[i]
                i += 1
            else:
                lista[k] = derecha[j]
                j += 1

            k += 1

        while i < len(izquierda):
            lista[k] = izquierda[i]
            i += 1
            k +=1

        while j < len(derecha):
            lista[k] = derecha[j]
            j += 1
            k += 1
        
        print(f'izquierda {izquierda}, derecha {derecha}')
        print(lista)
        print('-' * 50)

    return lista


if __name__ == '__main__':
    tamano_de_lista = int(input('De que tamano sera la lista? '))

    lista = [random.randint(0, 100) for i in range(tamano_de_lista)]
    print(lista)
    print('-' * 20)

    lista_ordenada = ordenamiento_por_mezcla(lista)
    print(lista_ordenada)
# Out:
# De que tamano sera la lista? 20
# [60, 5, 63, 68, 72, 15, 27, 74, 9, 29, 78, 91, 40, 92, 48, 52, 28, 25, 15, 90]
# --------------------
# [60, 5, 63, 68, 72, 15, 27, 74, 9, 29] ***** [78, 91, 40, 92, 48, 52, 28, 25, 15, 90]
# [60, 5, 63, 68, 72] ***** [15, 27, 74, 9, 29]
# [60, 5] ***** [63, 68, 72]
# [60] ***** [5]
# izquierda [60], derecha [5]
# [5, 60]
# --------------------------------------------------
# [63] ***** [68, 72]
# [68] ***** [72]
# izquierda [68], derecha [72]
# [68, 72]
# --------------------------------------------------
# izquierda [63], derecha [68, 72]
# [63, 68, 72]
# --------------------------------------------------
# izquierda [5, 60], derecha [63, 68, 72]
# [5, 60, 63, 68, 72]
# --------------------------------------------------
# [15, 27] ***** [74, 9, 29]
# [15] ***** [27]
# izquierda [15], derecha [27]
# [15, 27]
# --------------------------------------------------
# [74] ***** [9, 29]
# [9] ***** [29]
# izquierda [9], derecha [29]
# [9, 29]
# --------------------------------------------------
# izquierda [74], derecha [9, 29]
# [9, 29, 74]
# --------------------------------------------------
# izquierda [15, 27], derecha [9, 29, 74]
# [9, 15, 27, 29, 74]
# --------------------------------------------------
# izquierda [5, 60, 63, 68, 72], derecha [9, 15, 27, 29, 74]
# [5, 9, 15, 27, 29, 60, 63, 68, 72, 74]
# --------------------------------------------------
# [78, 91, 40, 92, 48] ***** [52, 28, 25, 15, 90]
# [78, 91] ***** [40, 92, 48]
# [78] ***** [91]
# izquierda [78], derecha [91]
# [78, 91]
# --------------------------------------------------
# [40] ***** [92, 48]
# [92] ***** [48]
# izquierda [92], derecha [48]
# [48, 92]
# --------------------------------------------------
# izquierda [40], derecha [48, 92]
# [40, 48, 92]
# --------------------------------------------------
# izquierda [78, 91], derecha [40, 48, 92]
# [40, 48, 78, 91, 92]
# --------------------------------------------------
# [52, 28] ***** [25, 15, 90]
# [52] ***** [28]
# izquierda [52], derecha [28]
# [28, 52]
# --------------------------------------------------
# [25] ***** [15, 90]
# [15] ***** [90]
# izquierda [15], derecha [90]
# [15, 90]
# --------------------------------------------------
# izquierda [25], derecha [15, 90]
# [15, 25, 90]
# --------------------------------------------------
# izquierda [28, 52], derecha [15, 25, 90]
# [15, 25, 28, 52, 90]
# --------------------------------------------------
# izquierda [40, 48, 78, 91, 92], derecha [15, 25, 28, 52, 90]
# [15, 25, 28, 40, 48, 52, 78, 90, 91, 92]
# --------------------------------------------------
# izquierda [5, 9, 15, 27, 29, 60, 63, 68, 72, 74], derecha [15, 25, 28, 40, 48, 52, 78, 90, 91, 92]
# [5, 9, 15, 15, 25, 27, 28, 29, 40, 48, 52, 60, 63, 68, 72, 74, 78, 90, 91, 92]
# --------------------------------------------------
# [5, 9, 15, 15, 25, 27, 28, 29, 40, 48, 52, 60, 63, 68, 72, 74, 78, 90, 91, 92]
